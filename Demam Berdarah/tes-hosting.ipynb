# %%
import streamlit as st
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
import pickle

# %%
# Fungsi untuk memuat model dan scaler yang telah disimpan
@st.cache_resource
def load_model_and_scaler():
    # Pastikan file model dan scaler tersimpan di folder yang sama
    with open('model.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('scaler.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    return model, scaler

# Muat model dan scaler
gnb, scaler = load_model_and_scaler()

# Judul aplikasi
st.title("Prediksi Infeksi Dengue dengan Naive Bayes")
st.write("Masukkan nilai untuk setiap fitur di bawah ini, lalu klik tombol 'Prediksi' untuk mendapatkan hasil.")

# Input data dari pengguna
temperature = st.number_input("Temperature (Fahrenheit)", min_value=90.0, max_value=110.0, step=0.1)
platelet_count = st.number_input("Platelet Count", min_value=10000.0, max_value=500000.0, step=100.0)
wbc_count = st.number_input("White Blood Cell Count", min_value=3000.0, max_value=20000.0, step=100.0)
body_pain = st.selectbox("Body Pain (Nyeri Badan)", options=[0, 1], format_func=lambda x: "No" if x == 0 else "Yes")
rash = st.selectbox("Rash (Ruam Kulit)", options=[0, 1], format_func=lambda x: "No" if x == 0 else "Yes")
gender = st.selectbox("Gender (Jenis Kelamin)", options=["Male", "Female"], format_func=lambda x: x)

# Konversi input menjadi DataFrame
input_data = pd.DataFrame([{
    'Temperature': temperature,
    'Platelet_Count': platelet_count,
    'White_Blood_Cell_Count': wbc_count,
    'Body_Pain': body_pain,
    'Rash': rash,
    'Gender': 0 if gender == "Female" else 1
}])

# Tombol untuk prediksi
if st.button("Prediksi"):
    # Preprocessing: Scaling data numerik
    input_data_scaled = scaler.transform(input_data)
    
    # Prediksi dengan model
    prediction = gnb.predict(input_data_scaled)
    
    # Tampilkan hasil prediksi
    st.write("Hasil Prediksi:")
    if prediction[0] == 1:
        st.success("Positif Terinfeksi Dengue!")
    else:
        st.error("Negatif, tidak terinfeksi Dengue.")
# Out:
# 2025-01-14 22:02:21.417 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.175
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\VICTUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-14 22:02:22.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.209 Session state does not function when running a script without `streamlit run`
# 2025-01-14 22:02:22.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 22:02:22.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
